# %% [markdown]
# # Подготовка библиотек

# %%
# !git clone https://github.com/bearpaw/clothing-co-parsing.git
# Out:
# fatal: destination path 'clothing-co-parsing' already exists and is not an empty directory.

# %%
import tensorflow as tf
from tensorflow.keras.utils import load_img, img_to_array

import matplotlib.pyplot as plt
import os
from scipy import io
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Проверить устройства для кераса

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14256131452672726535
# xla_global_id: -1
# ]

# %% [markdown]
# # Функции для визуализации

# %%
def display(display_list):
  title = ['Input Image', 'True Mask', 'Predicted Mask']

  plt.figure(figsize=(15, 15))
  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

def create_mask(pred_mask):
  pred_mask = tf.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

def show_predictions(model, dataset=None, num=1):
  if dataset:
    for image, mask in dataset.take(num):
      pred_mask = model.predict(image)
      display([image[0], mask[0], create_mask(pred_mask)])
  else:
    display([sample_image, sample_mask,
             create_mask(model.predict(sample_image[tf.newaxis, ...]))])

# %% [markdown]
# # Загрузка датасета и обработка

# %%
DATASET_PATH = 'clothing-co-parsing/photos/'
MASKS_PATH = 'clothing-co-parsing/annotations/pixel-level/'

# %%
def preprocess_image(image):
     image = tf.cast(image, tf.float32)
     # scale values to [0,1]
     image = image/255.0
     # resize image
     image = tf.image.resize(image, (128,128))
     return image 
     

def preprocess_mask(mask):
    mask = tf.expand_dims(mask, axis=-1)
    mask = tf.image.resize(mask, (128,128))
    # будем использовать бинарную классификацию - фон и человек
    # для этого фон, закодированный нулем, оставим нулевым
    # все остальное будет равно единице
    mask = tf.cast(mask != 0, tf.uint8)
    return mask

# %%
images = []
masks = []

for mask_filename in os.listdir(MASKS_PATH):
  image_filename = mask_filename[:-4] + '.jpg'
  image = img_to_array(load_img(DATASET_PATH + image_filename))
  images.append(preprocess_image(image))
      
  mask_file = io.loadmat(MASKS_PATH + mask_filename)
  mask = tf.convert_to_tensor(mask_file['groundtruth']) 
  masks.append(preprocess_mask(mask))

# %%
train_X, test_X, train_Y, test_Y = train_test_split(images, masks,\
                                                 test_size=0.2, random_state=0)
sample_image, sample_mask = train_X[0], train_Y[0]

train_X = tf.data.Dataset.from_tensor_slices(train_X)
test_X = tf.data.Dataset.from_tensor_slices(test_X)
train_Y = tf.data.Dataset.from_tensor_slices(train_Y)
test_Y = tf.data.Dataset.from_tensor_slices(test_Y)

train = tf.data.Dataset.zip((train_X, train_Y))
test = tf.data.Dataset.zip((test_X, test_Y))

# %%
# функции для аугментации 

# яркость
def brightness(img, mask):
    img = tf.image.adjust_brightness(img, 0.1)
    return img, mask

# оттенок
def hue(img, mask):
    img = tf.image.adjust_hue(img, -0.1)
    return img, mask

# отзеркаливание по горизонтали
def flip_horisontal(img, mask):
     img = tf.image.flip_left_right(img)
     mask = tf.image.flip_left_right(mask)
     return img, mask

# %%
# последовательно применяем аугментации
train = train.concatenate(train.map(brightness))
train = train.concatenate(train.map(hue))
train = train.concatenate(train.map(flip_horisontal))

# %%
len(train)
# Out:
# 6424

# %%
BATCH_SIZE = 32
BUFFER_SIZE = 500
train = train.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
train = train.prefetch(buffer_size=BUFFER_SIZE)
test = test.batch(BATCH_SIZE)

# %% [markdown]
# далее обучайте на датасете train, для валидации используйте датасет test аналогично как на занятии

# %%
display([sample_image, sample_mask])

# %%
tf.random.set_seed(0)

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[128, 128, 3], include_top=False)

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
]
layers = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=layers)

down_stack.trainable = False

# %%
up_stack = [
    tf.keras.layers.Conv2DTranspose(512, 3, strides=2, padding='same', 
                                    use_bias=False, activation='relu'),
    tf.keras.layers.Conv2DTranspose(256, 3, strides=2, padding='same', 
                                    use_bias=False, activation='relu'),
    tf.keras.layers.Conv2DTranspose(128, 3, strides=2, padding='same', 
                                    use_bias=False, activation='relu'),
    tf.keras.layers.Conv2DTranspose(64, 3, strides=2, padding='same', 
                                    use_bias=False, activation='relu'),
    tf.keras.layers.Conv2DTranspose(32,3, strides=2, padding='same', 
                                    use_bias=False, activation='relu')
]

# %%
def resolution_model(output_channels):
  inputs = tf.keras.layers.Input(shape=[128, 128, 3])
  x = inputs

  # Downsampling through the model
  skips = down_stack(x)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()
    x = concat([x, skip])

  # This is the last layer of the model
  last = tf.keras.layers.Conv2DTranspose(output_channels, 3, strides=2, 
                                         padding='same')  #64x64 -> 128x128

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
OUTPUT_CHANNELS = 3

model = resolution_model(OUTPUT_CHANNELS)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
show_predictions(model)
# Out:
# 1/1 [==============================] - 0s 361ms/step

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    show_predictions(model)
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))


EPOCHS = 15 # увеличьте при необходимости

model_history = model.fit(train, epochs=EPOCHS,
                          batch_size=BATCH_SIZE,
                          validation_data=test,
                          callbacks=[DisplayCallback()])
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
# Out:
# Epoch 1/15
# 1/1 [==============================] - 0s 20ms/step- loss: 0.1610 - accuracy: 0.93
# Sample Prediction after epoch 1
#
# 201/201 [==============================] - 73s 358ms/step - loss: 0.1610 - accuracy: 0.9349 - val_loss: 0.1007 - val_accuracy: 0.9602
# Epoch 2/15
# 1/1 [==============================] - 0s 21ms/step- loss: 0.0769 - accuracy: 0.96
# Sample Prediction after epoch 2
#
# 201/201 [==============================] - 72s 356ms/step - loss: 0.0769 - accuracy: 0.9697 - val_loss: 0.0832 - val_accuracy: 0.9680
# Epoch 3/15
# 1/1 [==============================] - 0s 21ms/step- loss: 0.0601 - accuracy: 0.97
# Sample Prediction after epoch 3
#
# 201/201 [==============================] - 72s 357ms/step - loss: 0.0601 - accuracy: 0.9766 - val_loss: 0.0775 - val_accuracy: 0.9709
# Epoch 4/15
# 1/1 [==============================] - 0s 21ms/step- loss: 0.0501 - accuracy: 0.98
# Sample Prediction after epoch 4
#
# 201/201 [==============================] - 73s 362ms/step - loss: 0.0501 - accuracy: 0.9805 - val_loss: 0.0764 - val_accuracy: 0.9724
# Epoch 5/15
# 1/1 [==============================] - 0s 22ms/step- loss: 0.0423 - accuracy: 0.98
# Sample Prediction after epoch 5
#
# 201/201 [==============================] - 73s 363ms/step - loss: 0.0423 - accuracy: 0.9834 - val_loss: 0.0807 - val_accuracy: 0.9723
# Epoch 6/15
# 1/1 [==============================] - 0s 20ms/step- loss: 0.0371 - accuracy: 0.98
# Sample Prediction after epoch 6
#
# 201/201 [==============================] - 72s 357ms/step - loss: 0.0371 - accuracy: 0.9854 - val_loss: 0.0840 - val_accuracy: 0.9726
# Epoch 7/15
# 1/1 [==============================] - 0s 21ms/step- loss: 0.0324 - accuracy: 0.98
# Sample Prediction after epoch 7
#
# 201/201 [==============================] - 72s 357ms/step - loss: 0.0324 - accuracy: 0.9872 - val_loss: 0.0881 - val_accuracy: 0.9728
# Epoch 8/15
# 1/1 [==============================] - 0s 21ms/step- loss: 0.0288 - accuracy: 0.98
# Sample Prediction after epoch 8
#
# 201/201 [==============================] - 74s 370ms/step - loss: 0.0288 - accuracy: 0.9886 - val_loss: 0.0911 - val_accuracy: 0.9730
# Epoch 9/15
# 1/1 [==============================] - 0s 23ms/step- loss: 0.0263 - accuracy: 0.98
# Sample Prediction after epoch 9
#
# 201/201 [==============================] - 77s 382ms/step - loss: 0.0263 - accuracy: 0.9895 - val_loss: 0.0936 - val_accuracy: 0.9730
# Epoch 10/15
# 1/1 [==============================] - 0s 21ms/step- loss: 0.0241 - accuracy: 0.99
# Sample Prediction after epoch 10
#
# 201/201 [==============================] - 76s 376ms/step - loss: 0.0241 - accuracy: 0.9904 - val_loss: 0.0971 - val_accuracy: 0.9733
# Epoch 11/15
# 1/1 [==============================] - 0s 22ms/step- loss: 0.0218 - accuracy: 0.99
# Sample Prediction after epoch 11
#
# 201/201 [==============================] - 79s 390ms/step - loss: 0.0218 - accuracy: 0.9913 - val_loss: 0.1017 - val_accuracy: 0.9730
# Epoch 12/15
# 1/1 [==============================] - 0s 22ms/step- loss: 0.0199 - accuracy: 0.99
# Sample Prediction after epoch 12
#
# 201/201 [==============================] - 77s 384ms/step - loss: 0.0199 - accuracy: 0.9921 - val_loss: 0.1052 - val_accuracy: 0.9732
# Epoch 13/15
# 1/1 [==============================] - 0s 23ms/step- loss: 0.0194 - accuracy: 0.99
# Sample Prediction after epoch 13
#
# 201/201 [==============================] - 79s 392ms/step - loss: 0.0194 - accuracy: 0.9923 - val_loss: 0.1061 - val_accuracy: 0.9730
# Epoch 14/15
# 1/1 [==============================] - 0s 42ms/step- loss: 0.0173 - accuracy: 0.99
# Sample Prediction after epoch 14
#
# 201/201 [==============================] - 74s 367ms/step - loss: 0.0173 - accuracy: 0.9931 - val_loss: 0.1157 - val_accuracy: 0.9731
# Epoch 15/15
# 1/1 [==============================] - 0s 21ms/step- loss: 0.0159 - accuracy: 0.99
# Sample Prediction after epoch 15
#
# 201/201 [==============================] - 74s 367ms/step - loss: 0.0159 - accuracy: 0.9937 - val_loss: 0.1211 - val_accuracy: 0.9728

# %%
epochs = range(EPOCHS)

plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
show_predictions(model, test, 3)
# Out:
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 230ms/step

# %% [markdown]
# Количество эпох и количество шагов помогает вырасти качеству, также как и увеличение encoder и decoder слоев, но после 8 - 10 эпох можно заканчивать, так как медленно растет validation loss.
